# %% [markdown]
# # Understanding Code and Markdown Cells
# This notebook demonstrates how to structure Jupyter notebooks professionally.

# %%
x=5

# %%
y=10

# %%
z=x+y

# %%
print(z)
# Out:
# 15

# %% [markdown]
# ## Adding Two Numbers
#
# The above code defines two variables and calculates their sum.
# The output shows the result of adding x and y.
